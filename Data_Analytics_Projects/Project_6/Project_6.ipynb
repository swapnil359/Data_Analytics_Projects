# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('udemy_courses.csv')

# %% [markdown]
# ## 1. Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %% [markdown]
# ## 2. Check Last 5 Rows of The Dataset

# %%
data.tail(5)
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# ## 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
print('Number of rows in dataset provided are:',data.shape[0])
print('Number of coumns in dataset provided are:',data.shape[1])
# Out:
# Number of rows in dataset provided are: 3678
# Number of coumns in dataset provided are: 12

# %%
data.shape
# Out:
# (3672, 14)

# %% [markdown]
# ## 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
print("Any Missing values?",data.isnull().values.any())
# Out:
# Any Missing values? False

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ## 6. Check For Duplicate Data and Drop Them

# %%
dup=data.duplicated().any()
print("Are there any duplicated values in data?",dup)
# Out:
# Are there any duplicated values in data? True

# %%
data=data.drop_duplicates()

# %%
dup=data.duplicated().any()
print("Are there any duplicated values in data?",dup)
# Out:
# Are there any duplicated values in data? False

# %% [markdown]
# ## 7. Find Out Number of Courses Per Subjects

# %%
data.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance

# %%
data['subject'].nunique()
# Out:
# 4

# %%
data['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
sns.countplot(x='subject',data=data)
plt.xlabel("Subjects",fontsize=13)
plt.ylabel("Number of courses Per Subject",fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %%
data['course_title'].nunique()
# Out:
# 3663

# %%
data['course_title'].value_counts()
# Out:
# course_title
# Acoustic Blues Guitar Lessons                                   3
# Creating an animated greeting card via Google Slides            3
# Aprende a tocar el acordeón de botones                          2
# Drum Lessons For Beginners                                      2
# Introduction to Web Development                                 2
#                                                                ..
# Illustrated Logo Design                                         1
# Color Basics for Print Designers                                1
# Digital Photo Manipulation Art And Cover Design In PhotoShop    1
# Drawing Perspective For Beginners                               1
# Using MODX CMS to Build Websites: A Beginner's Guide            1
# Name: count, Length: 3663, dtype: int64

# %% [markdown]
# ## 8. For Which Levels, Udemy Courses Providing The Courses

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['level'].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
sns.countplot(x='level',data=data)
plt.xlabel("level",fontsize=13)
plt.ylabel("Number of courses Per level",fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 9. Display The Count of Paid and Free Courses

# %%
filtered_data = data[data['course_title'].str.contains('develop', case=False, na=False)]

# %%
pd.set_option('display.max_rows', None)  # None means no limit
pd.set_option('display.max_columns', None)  # None means no limit

# %%
filtered_data
# Out:
#       course_id                                       course_title  \
# 243      337320  Cash Flow Valuation: Develop Your Financial Li...
# 1132     700140  Developing A Trading Strategy: Your Guide to T...
# 2105     620372  Piano for Kids: Developing Your Child's Creati...
# 2486     965528  Web Development Masterclass - Complete Certifi...
# 2493      94428        Learn Complete Web Development From Scratch
# 2494     159070              Introduction to Web Development: HTML
# 2500     924704  Ultimate Web Developer Course Build 10 Website...
# 2505    1009254  Beginner API development in Node, Express, ES6...
# 2507    1002030  Web Development w/ Google’s Go (golang) Progra...
# 2508     818990  Git a Web Developer Job: Mastering the Modern ...
# 2511     427530  Learn  Bootstrap Development By Building 10 Pr...
# 2513    1052118  Dissecting Ruby on Rails 5 - Become a Professi...
# 2519     736940   Practical CSS Website Development: Crash Course
# ...

# %%
sns.countplot(x='is_paid',data=data)
plt.xlabel("is_paid",fontsize=13)
plt.ylabel("Number of free and paid courses",fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 10. Which Course Has More Lectures (Free or Paid)?

# %%
data.head(100)
# Out:
#     course_id                                       course_title  \
# 0     1070968                 Ultimate Investment Banking Course
# 1     1113822  Complete GST Course & Certification - Grow You...
# 2     1006314  Financial Modeling for Business Analysts and C...
# 3     1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4     1011058       How To Maximize Your Profits Trading Options
# ..        ...                                                ...
# 95    1148774                    Options Trading 101: The Basics
# 96     959144                    Practical Accounts APP Overview
# 97    1233350                      Bitcoin Profits for Beginners
# 98     572744  Trend Traders Club: How To Find And Trade Fast...
# 99     724062                        Financial Statements Basics
#
#                                                   url  is_paid  price  \
# 0   https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['is_paid'].dtype
# Out:
# dtype('bool')

# %%
numeric_columns = data.select_dtypes(include=['number'])

# %%
result = data.groupby('is_paid')[numeric_columns.columns].mean()

# %%
print(result)
# Out:
#              course_id      price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False    691446.970968   0.000000     11533.951613   425.929032     21.416129
# True     674463.946163  72.198096      2421.270077   131.516359     41.866746
#
#          content_duration
# is_paid
# False            2.210753
# True             4.271584

# %% [markdown]
# ## 11. Which Courses Have A Higher Number of Subscribers Free or Paid?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
sns.barplot(x='is_paid',y='num_subscribers',data=data)
plt.show()

# %% [markdown]
# ## 12. Which Level Has The Highest Number of Subscribers?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['level'].unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
sns.barplot(x='level',y='num_subscribers',data=data)
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# ## 13. Find Most Popular Course Title

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data[data['num_subscribers'].max() == data['num_subscribers']]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# ## 14. Display 10 Most Popular Courses As Per Number of Subscribers

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
top_1=data.sort_values(by='num_subscribers',ascending=False).head(10)

# %%
sns.barplot(x='num_subscribers',y='course_title',data=top_1)
plt.show()

# %% [markdown]
# ## 15. Find The Course Which Is Having The Highest Number of Reviews.

# %%
data.sort_values(by='num_reviews',ascending=False).head(1)
# Out:
#       course_id                course_title  \
# 3230     625204  The Web Developer Bootcamp
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 3230           121584        27445           342  All Levels
#
#       content_duration   published_timestamp          subject
# 3230              43.0  2015-11-02T21:13:27Z  Web Development

# %%
sns.barplot(x='subject',y='num_reviews',data=data)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 16. Does Price Affect the Number of Reviews?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x='price',y='num_reviews',data=data)
plt.show()

# %% [markdown]
# ## 17. Find Total Number of Courses Related To Python

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
sum(data['course_title'].str.contains('python',case=False))
# Out:
# 29

# %% [markdown]
# ## 18. Display 10 Most Popular Python Courses As Per Number of Subscribers

# %%
python=data[data['course_title'].str.contains('python',case=False)].sort_values(by='num_subscribers',ascending=False).head(10)

# %%
sns.barplot(x='num_subscribers',y='course_title',data=python)
plt.show()

# %% [markdown]
# ## 19. In Which Year The Highest Number of Courses Were Posted?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
print(data['published_timestamp'].dtype)
# Out:
# object

# %%
data['published_timestamp'] = pd.to_datetime(data['published_timestamp'], errors='coerce')

# %%
data['year'] = data['published_timestamp'].dt.year

# %%
print(data['published_timestamp'].dtype)
# Out:
# datetime64[ns, UTC]

# %%
data['Year']=data['published_timestamp'].dt.year

# %%
data.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject  year  Year
# 0 2017-01-18 20:58:58+00:00  Business Finance  2017  2017

# %%
sns.countplot(x='Year',data=data)
plt.show()

# %% [markdown]
# ## 20. Display Category-Wise Count of Posted Subjects [Year Wise]

# %%
data.groupby('Year')['subject'].value_counts().unstack(fill_value=0)
# Out:
# subject  Business Finance  Graphic Design  Musical Instruments  \
# Year
# 2011                    0               0                    0
# 2012                    6              10                   10
# 2013                   84              23                   39
# 2014                  192              65                  120
# 2015                  339             168                  171
# 2016                  347             181                  228
# 2017                  223             155                  112
#
# subject  Web Development
# Year
# 2011                   5
# 2012                  19
# 2013                  55
# 2014                 113
# 2015                 336
# 2016                 448
# 2017                 223

# %%
result = pd.pivot_table(data, index='Year', columns='subject', aggfunc='size', fill_value=0)

print(result)
# Out:
# subject  Business Finance  Graphic Design  Musical Instruments  \
# Year
# 2011                    0               0                    0
# 2012                    6              10                   10
# 2013                   84              23                   39
# 2014                  192              65                  120
# 2015                  339             168                  171
# 2016                  347             181                  228
# 2017                  223             155                  112
#
# subject  Web Development
# Year
# 2011                   5
# 2012                  19
# 2013                  55
# 2014                 113
# 2015                 336
# 2016                 448
# 2017                 223
